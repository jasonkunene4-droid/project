# %%
import pandas as pd
df=pd.read_csv(r'/mnt/data/proj/dataset.csv')
df.head()
# Out:
#    Unnamed: 0        open  ...  crypto_name        date
# 0           0  112.900002  ...      Bitcoin  2013-05-05
# 1           1    3.493130  ...     Litecoin  2013-05-05
# 2           2  115.980003  ...      Bitcoin  2013-05-06
# 3           3    3.594220  ...     Litecoin  2013-05-06
# 4           4  112.250000  ...      Bitcoin  2013-05-07
#
# [5 rows x 10 columns]
